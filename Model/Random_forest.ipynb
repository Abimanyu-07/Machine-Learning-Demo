# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['target'] = iris.target

print("Iris Dataset - First 5 rows:")
display(iris_df.head())

print("\nIris Dataset - Info:")
iris_df.info()
# Out:
# Iris Dataset - First 5 rows:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# Iris Dataset - Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a pairplot of the iris_df, coloring by the 'target' column
sns.pairplot(iris_df, hue='target', palette='viridis')
plt.suptitle('Pairplot of Iris Dataset', y=1.02) # Adjust suptitle position
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

X_iris = iris_df.drop('target', axis=1)
y_iris = iris_df['target']

X_train_iris, X_test_iris, y_train_iris, y_test_iris = train_test_split(X_iris, y_iris, test_size=0.3, random_state=42)

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

feature_names = X_iris.columns.tolist()

iris_data = load_iris()
class_names = iris_data.target_names.tolist()

estimator = rf_model_iris.estimators_[0]

plt.figure(figsize=(20, 15))
plot_tree(estimator,
          feature_names=feature_names,
          class_names=class_names,
          filled=True,
          rounded=True,
          fontsize=10)
plt.title('First Decision Tree from Random Forest Classifier (Iris Dataset)')
plt.show()

# %%
rf_model_iris = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model_iris.fit(X_train_iris, y_train_iris)
y_pred_iris = rf_model_iris.predict(X_test_iris)

accuracy_iris = accuracy_score(y_test_iris, y_pred_iris)
print(f"Random Forest Model Accuracy on Iris Dataset: {accuracy_iris:.4f}")
# Out:
# Random Forest Model Accuracy on Iris Dataset: 1.0000
